# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset Euro_2012_stats_TEAM

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12=pd.read_csv("E:/python/PIAIC-Sir-Anees-Quarter-2-master/PIAIC-Sir-Anees-Quarter-2-master/Assignment-2/Euro_2012_stats_TEAM.csv")
display(euro12)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2848fe89166f> in <module>
# ----> 1 euro12=pd.read_csv("E:/python/PIAIC-Sir-Anees-Quarter-2-master/PIAIC-Sir-Anees-Quarter-2-master/Assignment-2/Euro_2012_stats_TEAM.csv")
#       2 display(euro12)
#
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12.Goals
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      5.0
# 4      3.0
# 5     10.0
# 6      5.0
# 7      6.0
# 8      2.0
# 9      2.0
# 10     6.0
# 11     1.0
# 12     5.0
# 13    12.0
# 14     5.0
# 15     2.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: Goals, dtype: float64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
c=0
for i in euro12.Team:
    c+=1
print("Teams are:",c)
# Out:
# Teams are: 20

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
y=euro12['Yellow Cards']
r=euro12['Red Cards']
t=euro12['Team']
d={"Yellow_card":y,"Red_card":r,"Teams":t}
discipline=pd.DataFrame(d)
display(discipline)
# Out:
#     Yellow_card  Red_card                                              Teams
# 0           9.0       0.0                                            Croatia
# 1           7.0       0.0                                     Czech Republic
# 2           4.0       0.0                                            Denmark
# 3           5.0       0.0                                            England
# 4           6.0       0.0                                             France
# 5           4.0       0.0                                            Germany
# 6           9.0       1.0                                             Greece
# 7          16.0       0.0                                              Italy
# 8           5.0       0.0                                        Netherlands
# 9           7.0       1.0                                             Poland
# 10         12.0       0.0                                           Portugal
# ...

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
s=discipline.sort_values(by="Red_card")
print(s)
aa=discipline.sort_values(by="Yellow_card")
print(aa)
# Out:
#     Yellow_card  Red_card                                              Teams
# 0           9.0       0.0                                            Croatia
# 1           7.0       0.0                                     Czech Republic
# 2           4.0       0.0                                            Denmark
# 3           5.0       0.0                                            England
# 4           6.0       0.0                                             France
# 5           4.0       0.0                                            Germany
# 7          16.0       0.0                                              Italy
# 8           5.0       0.0                                        Netherlands
# 10         12.0       0.0                                           Portugal
# 12          6.0       0.0                                             Russia
# 13         11.0       0.0                                              Spain
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
#discipline.fillna({'Yellow_card':0})
df=discipline.fillna(0)
display(df)
sum=0
c=0
for h in df["Yellow_card"]:
    h=float(h)
    sum=sum+h
    c+=1
print("Mean",sum/c)
# Out:
#     Yellow_card  Red_card                                              Teams
# 0           9.0       0.0                                            Croatia
# 1           7.0       0.0                                     Czech Republic
# 2           4.0       0.0                                            Denmark
# 3           5.0       0.0                                            England
# 4           6.0       0.0                                             France
# 5           4.0       0.0                                            Germany
# 6           9.0       1.0                                             Greece
# 7          16.0       0.0                                              Italy
# 8           5.0       0.0                                        Netherlands
# 9           7.0       1.0                                             Poland
# 10         12.0       0.0                                           Portugal
# ...

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12.Goals>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany   10.0             32.0              32.0            47.80%
# 13    Spain   12.0             42.0              33.0            55.90%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.60%                        80.0           2.0            1.0
# 13           16.00%                       100.0           0.0            1.0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                    0.0  ...        10.0                62.60%       63.0
# 13                   0.0  ...        15.0                93.80%      102.0
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5            49.0      12.0           4.0        0.0     15.0      15.0
# 13           83.0      19.0          11.0        0.0     17.0      17.0
#
#     Players Used
# 5           17.0
# 13          18.0
#
# ...

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
df=euro12.fillna({"Team":"mising"})
#print(df)
for i in df.Team:
    if i.startswith("G"):
        print(i)
# Out:
# Germany
# Greece

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12.iloc[0:,:7]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12.iloc[:,:-3]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro1=pd.read_csv("E:/python/PIAIC-Sir-Anees-Quarter-2-master/PIAIC-Sir-Anees-Quarter-2-master/Assignment-2/Euro_2012_stats_TEAM.csv",index_col="Team")
#display(euro12)
euro1.index_col='Team'
euro1.loc[['England','Italy','Russia'],["Shooting Accuracy"]]
# Out:
#         Shooting Accuracy
# Team
# England            50.00%
# Italy              43.00%
# Russia             22.50%

# %% [markdown]
# ### Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
#
# 1. If Goals are less than or equal to 2, peformance is **Below Avg**
# 2. If Goals are more than 2 and less than or equal to 5, peformance is **Average**
# 3. If Goals are more than 5 and less than or equal to 10, peformance is **Above Average**
# 4. If Goals are more than 10 then peformance is **Excellent**

# %%
#print(euro12.Goals)
s=pd.Series(euro12.Goals)
for i in s:
    if i<=2:
        print("Below Average=",i)
    elif i>=2 and i<=5:
        print(" Average=",i)
    elif i>=5 and i<=10:
        print(" above average=",i)
    else:
        print('excellent')
# Out:
#  Average= 4.0
#  Average= 4.0
#  Average= 4.0
#  Average= 5.0
#  Average= 3.0
#  above average= 10.0
#  Average= 5.0
#  above average= 6.0
# Below Average= 2.0
# Below Average= 2.0
#  above average= 6.0
# Below Average= 1.0
#  Average= 5.0
# excellent
#  Average= 5.0
# Below Average= 2.0
# excellent
# excellent
# excellent
# excellent
